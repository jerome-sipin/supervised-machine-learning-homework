# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %%
train_df = pd.read_csv(Path('Resources/2019loans.csv'))
test_df = pd.read_csv(Path('Resources/2020Q1loans.csv'))

# %%
# Pandas df display settings
pd.set_option('display.max_columns', 16)
pd.set_option('display.max_rows', 16)

# %%
train_df.head()
# Out:
#    Unnamed: 0   index  loan_amnt  int_rate  installment home_ownership  \
# 0       57107   57107    13375.0    0.1797       483.34       MORTGAGE
# 1      141451  141451    21000.0    0.1308       478.68       MORTGAGE
# 2      321143  321143    20000.0    0.1240       448.95       MORTGAGE
# 3       11778   11778     3000.0    0.1240       100.22           RENT
# 4      169382  169382    30000.0    0.1612      1056.49       MORTGAGE
#
#    annual_inc verification_status  ... pub_rec_bankruptcies tax_liens  \
# 0    223000.0        Not Verified  ...                  0.0       0.0
# 1    123000.0     Source Verified  ...                  0.0       0.0
# 2    197000.0     Source Verified  ...                  0.0       0.0
# 3     45000.0        Not Verified  ...                  1.0       0.0
# 4    133000.0     Source Verified  ...                  0.0       0.0
#
#    tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0         577150.0           122018.0         32000.0
# 1         132750.0            27896.0         15900.0
# 2         628160.0           114043.0         22600.0
# 3          42006.0            20761.0         19900.0
# 4         283248.0           109056.0         79500.0
#
#    total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                    170200.0              N                     N
# 1                     35398.0              N                     N
# 2                     90340.0              N                     N
# 3                     15406.0              N                     N
# 4                     58778.0              N                     N
#
# [5 rows x 86 columns]

# %%
test_df.head()
# Out:
#    Unnamed: 0  index  loan_amnt  int_rate  installment home_ownership  \
# 0       67991  67991    40000.0    0.0819       814.70       MORTGAGE
# 1       25429  25429     6000.0    0.1524       208.70           RENT
# 2       38496  38496     3600.0    0.1695       128.27           RENT
# 3       19667  19667    20000.0    0.1524       478.33           RENT
# 4       37505  37505     3600.0    0.1240       120.27           RENT
#
#    annual_inc verification_status  ... pub_rec_bankruptcies tax_liens  \
# 0    140000.0        Not Verified  ...                  0.0       0.0
# 1     55000.0        Not Verified  ...                  0.0       0.0
# 2     42000.0        Not Verified  ...                  0.0       0.0
# 3    100000.0        Not Verified  ...                  0.0       0.0
# 4     50000.0        Not Verified  ...                  0.0       0.0
#
#    tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 0         527975.0            70914.0         74600.0
# 1          34628.0            23460.0          5900.0
# 2          23100.0            19183.0          7300.0
# 3          56481.0            43817.0         13800.0
# 4          45977.0            32448.0         21000.0
#
#    total_il_high_credit_limit  hardship_flag  debt_settlement_flag
# 0                     99475.0              N                     N
# 1                     23628.0              N                     N
# 2                     15000.0              N                     N
# 3                     35981.0              N                     N
# 4                     24977.0              N                     N
#
# [5 rows x 86 columns]

# %%
# Convert categorical data to numeric and separate target feature for training data
train_df = pd.get_dummies(train_df)
train_df.head()
# Out:
#    Unnamed: 0   index  loan_amnt  int_rate  installment  annual_inc    dti  \
# 0       57107   57107    13375.0    0.1797       483.34    223000.0  29.99
# 1      141451  141451    21000.0    0.1308       478.68    123000.0  11.26
# 2      321143  321143    20000.0    0.1240       448.95    197000.0  11.28
# 3       11778   11778     3000.0    0.1240       100.22     45000.0  18.08
# 4      169382  169382    30000.0    0.1612      1056.49    133000.0  27.77
#
#    delinq_2yrs  ...  initial_list_status_f  initial_list_status_w  \
# 0          0.0  ...                      0                      1
# 1          2.0  ...                      0                      1
# 2          0.0  ...                      0                      1
# 3          0.0  ...                      0                      1
# 4          0.0  ...                      0                      1
#
#    application_type_Individual  application_type_Joint App  hardship_flag_N  \
# 0                            1                           0                1
# 1                            1                           0                1
# 2                            1                           0                1
# 3                            1                           0                1
# 4                            1                           0                1
#
#    hardship_flag_Y  debt_settlement_flag_N  debt_settlement_flag_Y
# 0                0                       1                       0
# 1                0                       1                       0
# 2                0                       1                       0
# 3                0                       1                       0
# 4                0                       1                       0
#
# [5 rows x 96 columns]

# %%
# Convert categorical data to numeric and separate target feature for testing data
test_df = pd.get_dummies(test_df)
test_df.head()
# Out:
#    Unnamed: 0  index  loan_amnt  int_rate  installment  annual_inc    dti  \
# 0       67991  67991    40000.0    0.0819       814.70    140000.0  19.75
# 1       25429  25429     6000.0    0.1524       208.70     55000.0  11.52
# 2       38496  38496     3600.0    0.1695       128.27     42000.0   6.74
# 3       19667  19667    20000.0    0.1524       478.33    100000.0  12.13
# 4       37505  37505     3600.0    0.1240       120.27     50000.0  16.08
#
#    delinq_2yrs  ...  pymnt_plan_n  initial_list_status_f  \
# 0          0.0  ...             1                      0
# 1          2.0  ...             1                      0
# 2          0.0  ...             1                      0
# 3          0.0  ...             1                      0
# 4          0.0  ...             1                      0
#
#    initial_list_status_w  application_type_Individual  \
# 0                      1                            1
# 1                      1                            1
# 2                      1                            1
# 3                      1                            1
# 4                      1                            1
#
#    application_type_Joint App  hardship_flag_N  hardship_flag_Y  \
# 0                           0                1                0
# 1                           0                1                0
# 2                           0                1                0
# 3                           0                1                0
# 4                           0                1                0
#
#    debt_settlement_flag_N
# 0                       1
# 1                       1
# 2                       1
# 3                       1
# 4                       1
#
# [5 rows x 95 columns]

# %%
# add missing dummy variables to testing set
test_df["debt_settlement_flag_Y"] = 0
test_df.head()
# Out:
#    Unnamed: 0  index  loan_amnt  int_rate  installment  annual_inc    dti  \
# 0       67991  67991    40000.0    0.0819       814.70    140000.0  19.75
# 1       25429  25429     6000.0    0.1524       208.70     55000.0  11.52
# 2       38496  38496     3600.0    0.1695       128.27     42000.0   6.74
# 3       19667  19667    20000.0    0.1524       478.33    100000.0  12.13
# 4       37505  37505     3600.0    0.1240       120.27     50000.0  16.08
#
#    delinq_2yrs  ...  initial_list_status_f  initial_list_status_w  \
# 0          0.0  ...                      0                      1
# 1          2.0  ...                      0                      1
# 2          0.0  ...                      0                      1
# 3          0.0  ...                      0                      1
# 4          0.0  ...                      0                      1
#
#    application_type_Individual  application_type_Joint App  hardship_flag_N  \
# 0                            1                           0                1
# 1                            1                           0                1
# 2                            1                           0                1
# 3                            1                           0                1
# 4                            1                           0                1
#
#    hardship_flag_Y  debt_settlement_flag_N  debt_settlement_flag_Y
# 0                0                       1                       0
# 1                0                       1                       0
# 2                0                       1                       0
# 3                0                       1                       0
# 4                0                       1                       0
#
# [5 rows x 96 columns]

# %%
# Train the Logistic Regression model on the unscaled data and print the model score

# %%
# Train a Random Forest Classifier model and print the model score

# %%
# Scale the data

# %%
# Train the Logistic Regression model on the scaled data and print the model score

# %%
# Train a Random Forest Classifier model on the scaled data and print the model score
